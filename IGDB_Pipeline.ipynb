# %% [markdown]
# # Section 1 - Pulling data from API Endpoints and Cleaning
# Libraries

# %%
import os
import pandas as pd
import numpy as np
import requests
from dotenv import load_dotenv

# %%
load_dotenv('env.txt')
# Out:
# True

# %% [markdown]
# Set up credentials

# %%
auth_url = 'https://id.twitch.tv/oauth2/token'
cred = {'client_id': os.getenv('CLIENT_ID'),
           'client_secret': os.getenv('CLIENT_SECRET'),
           'grant_type':'client_credentials'}
r = requests.post(auth_url, data=cred)
data = r.json()
print('Bearer '+data['access_token'])

base_url = 'https://api.igdb.com/v4'
header = {'Client-ID': os.getenv('CLIENT_ID'),
           'Authorization': 'Bearer '+data['access_token']}
# Out:
# Bearer gue3so1g7soa41j1xtr37cyd3mauzm

# %% [markdown]
# ## Games Endpoint
# ### games table

# %%
r = requests.post(base_url+'/games', headers=header,
data='''fields name, category, first_release_date, status,
aggregated_rating, aggregated_rating_count, rating, rating_count,
total_rating, total_rating_count; where category = 0; limit 100;''')
games_table = r.json()
games_table_df = pd.DataFrame(games_table)

games_table_df
# Out:
#         id  category  first_release_date  \
# 0    35004         0        1.437696e+09
# 1   176043         0                 NaN
# 2    89616         0                 NaN
# 3   118008         0        1.589501e+09
# 4    95080         0                 NaN
# ..     ...       ...                 ...
# 95   77236         0        1.131667e+09
# 96   70621         0                 NaN
# 97  137234         0                 NaN
# 98  137242         0                 NaN
# 99   66013         0        9.114336e+08
#
#                                          name  status  rating  rating_count  \
# 0                          Demon Horde Master     NaN     NaN           NaN
# 1                                 Zero Racers     6.0     NaN           NaN
# 2                        Bubble Whirl Shooter     8.0     NaN           NaN
# 3                         Tabletop Playground     4.0     NaN           NaN
# 4                                       Dotra     NaN     NaN           NaN
# ..                                        ...     ...     ...           ...
# 95  Fengse Huanxiang 4: Shengzhan de Zhongyan     NaN     NaN           NaN
# 96                               Fruit Attack     NaN     NaN           NaN
# 97                                  Slip Slop     NaN     NaN           NaN
# 98                     Premier Collection III     NaN     NaN           NaN
# 99        Simple 1500 Series Vol. 7: The Card     NaN     NaN           NaN
#
#     total_rating  total_rating_count  aggregated_rating  \
# 0            NaN                 NaN                NaN
# 1            NaN                 NaN                NaN
# 2            NaN                 NaN                NaN
# 3            NaN                 NaN                NaN
# 4            NaN                 NaN                NaN
# ..           ...                 ...                ...
# 95           NaN                 NaN                NaN
# 96           NaN                 NaN                NaN
# 97           NaN                 NaN                NaN
# 98           NaN                 NaN                NaN
# 99           NaN                 NaN                NaN
#
#     aggregated_rating_count
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 95                      NaN
# 96                      NaN
# 97                      NaN
# 98                      NaN
# 99                      NaN
#
# [100 rows x 11 columns]

# %% [markdown]
# ### genres table

# %%
r = requests.post(base_url+'/games', headers=header,
data='fields genres; limit 100;')
genres_table = r.json()
genres_table_df =pd.DataFrame(genres_table).explode('genres')
genres_table_df['genre_key'] = np.arange(genres_table_df.shape[0]) + 1
genres_table_df
# Out:
#         id genres  genre_key
# 0    35004     15          1
# 0    35004     32          2
# 1   176043     10          3
# 2    89616      9          4
# 2    89616     33          5
# ..     ...    ...        ...
# 96  123238     32        140
# 97  196510     15        141
# 97  196510     32        142
# 98   88217    NaN        143
# 99  209902    NaN        144
#
# [144 rows x 3 columns]

# %% [markdown]
# ### keywords table

# %%
r = requests.post(base_url+'/games', headers=header,
data='fields keywords; limit 100;')
keywords_table = r.json()
keywords_table_df =pd.DataFrame(keywords_table).explode('keywords')
keywords_table_df['keyword_key'] = np.arange(keywords_table_df.shape[0]) + 1
keywords_table_df
# Out:
#         id keywords  keyword_key
# 0    35004      NaN            1
# 1   176043     5340            2
# 1   176043    23861            3
# 2    89616      NaN            4
# 3   118008      NaN            5
# ..     ...      ...          ...
# 95   51648     1026          165
# 96  123238     3257          166
# 97  196510      NaN          167
# 98   88217      NaN          168
# 99  209902      NaN          169
#
# [169 rows x 3 columns]

# %% [markdown]
# ### platforms table

# %%
r = requests.post(base_url+'/games', headers=header,
data='fields platforms; limit 100;')
platforms_table = r.json()
platforms_table_df =pd.DataFrame(platforms_table).explode('platforms')
platforms_table_df['platform_key'] = np.arange(platforms_table_df.shape[0]) + 1
platforms_table_df
# Out:
#         id platforms  platform_key
# 0    35004         6             1
# 1   176043        87             2
# 2    89616        34             3
# 2    89616        39             4
# 3   118008         6             5
# ..     ...       ...           ...
# 95   51648         6           112
# 96  123238         6           113
# 97  196510       NaN           114
# 98   88217       NaN           115
# 99  209902         6           116
#
# [116 rows x 3 columns]

# %% [markdown]
# ## Genres Endpoint
# ### genres_info table

# %%
r = requests.post(base_url+'/genres', headers=header, data='fields name; limit 100;')
genre_info_table = r.json()
genre_info_table_df = pd.DataFrame(genre_info_table)
genre_info_table_df.head()
# Out:
#    id      name
# 0   4  Fighting
# 1   5   Shooter
# 2   7     Music
# 3   8  Platform
# 4   9    Puzzle

# %% [markdown]
# ## Keyword Endpoint
# ### keyword_info_table

# %%
r = requests.post(base_url+'/keywords', headers=header, data='fields slug; limit 100;')
keyword_info_table = r.json()
keyword_info_table_df = pd.DataFrame(keyword_info_table)
keyword_info_table_df.head()
# Out:
#       id          slug
# 0   3576            oi
# 1   4010     argentina
# 2  13017        fremen
# 3   1027     adventure
# 4  19226  fight-trivia

# %% [markdown]
# ## Platform Endpoint
# ### Platform Table

# %%
r = requests.post(base_url+'/platforms', headers=header, data='fields name, platform_family; limit 100;')
platform_info_table = r.json()
platform_info_table_df = pd.DataFrame(platform_info_table)
platform_info_table_df.head()
# Out:
#     id              name  platform_family
# 0  158    Commodore CDTV              NaN
# 1  339         Sega Pico              3.0
# 2    8     PlayStation 2              1.0
# 3   39               iOS              NaN
# 4   94  Commodore Plus/4              NaN

# %% [markdown]
# # Section 2 - Upload to MySQL Server
